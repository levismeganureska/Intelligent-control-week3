# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Direktori dataset
train_dir = "dataset/seg_train/seg_train"
val_dir = "dataset/seg_test/seg_test"

# %%
# Augmentasi data
train_datagen = ImageDataGenerator(rescale=1./255, rotation_range=20, zoom_range=0.2, 
horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(train_dir, target_size=(150, 150), 
batch_size=32, class_mode='categorical')
val_generator = val_datagen.flow_from_directory(val_dir, target_size=(150, 150), batch_size=32, 
class_mode='categorical')
# Out:
# Found 14034 images belonging to 6 classes.
# Found 3000 images belonging to 6 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
 # Definisi model CNN
model = Sequential([
 Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
 MaxPooling2D(2,2),
 Conv2D(64, (3,3), activation='relu'),
 MaxPooling2D(2,2),
 Flatten(),
 Dense(128, activation='relu'),
 Dropout(0.5),
 Dense(6, activation='softmax')
 ])

# %%
 # Kompilasi model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Training model
model.fit(train_generator, validation_data=val_generator, epochs=10)
# Out:
# Epoch 1/10
# 439/439 [==============================] - 425s 964ms/step - loss: 1.1746 - accuracy: 0.5524 - val_loss: 0.8783 - val_accuracy: 0.6860
# Epoch 2/10
# 439/439 [==============================] - 291s 662ms/step - loss: 0.8919 - accuracy: 0.6674 - val_loss: 0.7335 - val_accuracy: 0.7350
# Epoch 3/10
# 439/439 [==============================] - 284s 647ms/step - loss: 0.8052 - accuracy: 0.7097 - val_loss: 0.6182 - val_accuracy: 0.7900
# Epoch 4/10
# 439/439 [==============================] - 284s 646ms/step - loss: 0.7476 - accuracy: 0.7319 - val_loss: 0.6100 - val_accuracy: 0.7943
# Epoch 5/10
# 439/439 [==============================] - 298s 679ms/step - loss: 0.7070 - accuracy: 0.7478 - val_loss: 0.5834 - val_accuracy: 0.8090
# Epoch 6/10
# 439/439 [==============================] - 300s 683ms/step - loss: 0.6698 - accuracy: 0.7633 - val_loss: 0.5842 - val_accuracy: 0.7990
# Epoch 7/10
# 439/439 [==============================] - 298s 679ms/step - loss: 0.6438 - accuracy: 0.7698 - val_loss: 0.5931 - val_accuracy: 0.7987
# Epoch 8/10
# 439/439 [==============================] - 302s 687ms/step - loss: 0.6086 - accuracy: 0.7850 - val_loss: 0.5011 - val_accuracy: 0.8363
# Epoch 9/10
# 439/439 [==============================] - 306s 697ms/step - loss: 0.6014 - accuracy: 0.7909 - val_loss: 0.5172 - val_accuracy: 0.8197
# Epoch 10/10
# 439/439 [==============================] - 298s 679ms/step - loss: 0.5942 - accuracy: 0.7896 - val_loss: 0.4927 - val_accuracy: 0.8323

# %%
# Simpan model
model.save('cnn_model.h5')
